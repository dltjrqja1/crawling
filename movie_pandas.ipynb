# %%
import pandas as pd

# %%
movie = pd.read_csv('./movie_df.csv',sep=',',index_col=[0])

# %%
movie
# Out:
#                   title      age  Advance_rate  rating  \
# 0                겨울왕국 2   전체 관람가         47.13    8.68
# 1           쥬만지: 넥스트 레벨  12세 관람가         21.70    6.17
# 2              포드 V 페라리  12세 관람가         14.48    9.56
# 3               나이브스 아웃  12세 관람가          5.72    9.12
# 4               감쪽같은 그녀   전체 관람가          2.61    7.54
# ..                  ...      ...           ...     ...
# 109             포레스트 검프  12세 관람가          0.01    9.39
# 110               더 포스트  12세 관람가           NaN    8.73
# 111               멋진 하루  12세 관람가           NaN    8.17
# 112  미스 사이공: 25주년 특별 공연  15세 관람가           NaN    9.20
# 113                  밀양  15세 관람가           NaN    7.87
#
#                       genres
# 0    애니메이션 모험 코미디 가족 판타지 뮤지컬
# 1                      액션 모험
# 2                     액션 드라마
# 3                   미스터리 스릴러
# 4                        드라마
# ..                       ...
# 109                  드라마 코미디
# 110                  드라마 스릴러
# 111               드라마 멜로/로맨스
# 112                     공연실황
# 113                      드라마
#
# [114 rows x 5 columns]

# %%
movie = movie.fillna(0)

# %%
movie
# Out:
#                   title      age  Advance_rate  rating  \
# 0                겨울왕국 2   전체 관람가         47.13    8.68
# 1           쥬만지: 넥스트 레벨  12세 관람가         21.70    6.17
# 2              포드 V 페라리  12세 관람가         14.48    9.56
# 3               나이브스 아웃  12세 관람가          5.72    9.12
# 4               감쪽같은 그녀   전체 관람가          2.61    7.54
# ..                  ...      ...           ...     ...
# 109             포레스트 검프  12세 관람가          0.01    9.39
# 110               더 포스트  12세 관람가          0.00    8.73
# 111               멋진 하루  12세 관람가          0.00    8.17
# 112  미스 사이공: 25주년 특별 공연  15세 관람가          0.00    9.20
# 113                  밀양  15세 관람가          0.00    7.87
#
#                       genres
# 0    애니메이션 모험 코미디 가족 판타지 뮤지컬
# 1                      액션 모험
# 2                     액션 드라마
# 3                   미스터리 스릴러
# 4                        드라마
# ..                       ...
# 109                  드라마 코미디
# 110                  드라마 스릴러
# 111               드라마 멜로/로맨스
# 112                     공연실황
# 113                      드라마
#
# [114 rows x 5 columns]

# %%
movie = movie[(movie['Advance_rate']>0.01)]
movie
# Out:
#                         title       age  Advance_rate  rating  \
# 0                      겨울왕국 2    전체 관람가         47.13    8.68
# 1                 쥬만지: 넥스트 레벨   12세 관람가         21.70    6.17
# 2                    포드 V 페라리   12세 관람가         14.48    9.56
# 3                     나이브스 아웃   12세 관람가          5.72    9.12
# 4                     감쪽같은 그녀    전체 관람가          2.61    7.54
# 5                     아내를 죽였다   15세 관람가          1.89    5.67
# 6                   라스트 크리스마스   12세 관람가          1.37    6.74
# 7                       카운트다운   15세 관람가          0.99    6.80
# 8                        블랙머니   12세 관람가          0.78    8.52
# 9                        윤희에게   12세 관람가          0.40    9.19
# 10                       두 교황   12세 관람가          0.23    9.00
# 11                     나를 찾아줘   15세 관람가          0.20    7.08
# 12                파비안느에 관한 진실   12세 관람가          0.20    8.35
# 13           아스테릭스: 마법 물약의 비밀    전체 관람가          0.19    8.50
# 14                     결혼 이야기   15세 관람가          0.13    9.08
# 15                      아이리시맨  청소년 관람불가          0.11    8.91
# 17                   대통령의 7시간   12세 관람가          0.08    6.27
# 18                   82년생 김지영   12세 관람가          0.07    6.69
# 19       프란치스코 교황: 맨 오브 히스 워드    전체 관람가          0.06    8.55
# 20                      블랙 스완  청소년 관람불가          0.06    8.69
# 21                         매리   15세 관람가          0.06    7.09
# 22                    드래곤 빌리지    전체 관람가          0.05    7.00
# 23                     날씨의 아이   15세 관람가          0.05    7.88
# 24                        속물들   15세 관람가          0.05    8.63
# 25                        디에고   12세 관람가          0.05    8.67
# 26                        이태원   15세 관람가          0.05    9.84
# 27                         월성    전체 관람가          0.04    7.12
# 28                         벌새   15세 관람가          0.04    8.90
# 29              터미네이터: 다크 페이트   15세 관람가          0.03    8.63
# 30                      굿 라이어   15세 관람가          0.03    8.32
# 31                         조커   15세 관람가          0.03    8.65
# 32  극장판 타오르지마 버스터 - 블랙어썰트의 귀환    전체 관람가          0.03    9.70
# 33                  어메이징 그레이스    전체 관람가          0.03    8.53
# 34                       헤로니모    전체 관람가          0.03    9.62
# 35                      집 이야기   12세 관람가          0.02    9.31
# 36                    영화로운 나날   12세 관람가          0.02    9.33
# 37                   산타 앤 컴퍼니    전체 관람가          0.02    9.14
# 38                         크롤   15세 관람가          0.02    6.96
#
#                      genres
# 0   애니메이션 모험 코미디 가족 판타지 뮤지컬
# 1                     액션 모험
# 2                    액션 드라마
# 3                  미스터리 스릴러
# 4                       드라마
# 5                    스릴러 액션
# 6                멜로/로맨스 코미디
# 7                    공포 스릴러
# 8                    범죄 드라마
# 9                    멜로/로맨스
# 10                      드라마
# 11                      스릴러
# 12                      드라마
# 13         애니메이션 코미디 가족 판타지
# 14                  코미디 드라마
# 15               범죄 드라마 스릴러
# 17                    다큐멘터리
# 18                      드라마
# 19                    다큐멘터리
# 20                  드라마 스릴러
# 21                   공포 스릴러
# 22            애니메이션 판타지 코미디
# 23                    애니메이션
# 24                      드라마
# 25                    다큐멘터리
# 26                    다큐멘터리
# 27                    다큐멘터리
# 28                      드라마
# 29                    SF 액션
# 30                      스릴러
# 31                  스릴러 드라마
# 32          애니메이션 코미디 액션 모험
# 33                    다큐멘터리
# 34                    다큐멘터리
# 35                      드라마
# 36           멜로/로맨스 판타지 드라마
# 37                   코미디 가족
# 38                   액션 스릴러

# %%
movie.groupby('age').describe()
# Out:
#          Advance_rate                                                    \
#                 count      mean        std   min     25%    50%     75%
# age
# 12세 관람가          13.0  3.470769   6.827826  0.02  0.0700  0.230  1.3700
# 15세 관람가          13.0  0.274615   0.551099  0.02  0.0300  0.050  0.1300
# 전체 관람가           10.0  5.019000  14.818128  0.02  0.0300  0.045  0.1575
# 청소년 관람불가          2.0  0.085000   0.035355  0.06  0.0725  0.085  0.0975
#
#                 rating
#             max  count      mean       std   min    25%   50%    75%   max
# age
# 12세 관람가   21.70   13.0  8.224615  1.272154  6.17  6.740  8.67  9.190  9.56
# 15세 관람가    1.89   13.0  7.963846  1.165587  5.67  7.080  8.32  8.650  9.84
# 전체 관람가    47.13   10.0  8.438000  0.953203  7.00  7.780  8.54  9.025  9.70
# 청소년 관람불가   0.11    2.0  8.800000  0.155563  8.69  8.745  8.80  8.855  8.91

# %%
movie.sort_values(by='rating',axis=0,ascending=False)
# Out:
#                         title       age  Advance_rate  rating  \
# 26                        이태원   15세 관람가          0.05    9.84
# 32  극장판 타오르지마 버스터 - 블랙어썰트의 귀환    전체 관람가          0.03    9.70
# 34                       헤로니모    전체 관람가          0.03    9.62
# 2                    포드 V 페라리   12세 관람가         14.48    9.56
# 36                    영화로운 나날   12세 관람가          0.02    9.33
# 35                      집 이야기   12세 관람가          0.02    9.31
# 9                        윤희에게   12세 관람가          0.40    9.19
# 37                   산타 앤 컴퍼니    전체 관람가          0.02    9.14
# 3                     나이브스 아웃   12세 관람가          5.72    9.12
# 14                     결혼 이야기   15세 관람가          0.13    9.08
# 10                       두 교황   12세 관람가          0.23    9.00
# 15                      아이리시맨  청소년 관람불가          0.11    8.91
# 28                         벌새   15세 관람가          0.04    8.90
# 20                      블랙 스완  청소년 관람불가          0.06    8.69
# 0                      겨울왕국 2    전체 관람가         47.13    8.68
# 25                        디에고   12세 관람가          0.05    8.67
# 31                         조커   15세 관람가          0.03    8.65
# 29              터미네이터: 다크 페이트   15세 관람가          0.03    8.63
# 24                        속물들   15세 관람가          0.05    8.63
# 19       프란치스코 교황: 맨 오브 히스 워드    전체 관람가          0.06    8.55
# 33                  어메이징 그레이스    전체 관람가          0.03    8.53
# 8                        블랙머니   12세 관람가          0.78    8.52
# 13           아스테릭스: 마법 물약의 비밀    전체 관람가          0.19    8.50
# 12                파비안느에 관한 진실   12세 관람가          0.20    8.35
# 30                      굿 라이어   15세 관람가          0.03    8.32
# 23                     날씨의 아이   15세 관람가          0.05    7.88
# 4                     감쪽같은 그녀    전체 관람가          2.61    7.54
# 27                         월성    전체 관람가          0.04    7.12
# 21                         매리   15세 관람가          0.06    7.09
# 11                     나를 찾아줘   15세 관람가          0.20    7.08
# 22                    드래곤 빌리지    전체 관람가          0.05    7.00
# 38                         크롤   15세 관람가          0.02    6.96
# 7                       카운트다운   15세 관람가          0.99    6.80
# 6                   라스트 크리스마스   12세 관람가          1.37    6.74
# 18                   82년생 김지영   12세 관람가          0.07    6.69
# 17                   대통령의 7시간   12세 관람가          0.08    6.27
# 1                 쥬만지: 넥스트 레벨   12세 관람가         21.70    6.17
# 5                     아내를 죽였다   15세 관람가          1.89    5.67
#
#                      genres
# 26                    다큐멘터리
# 32          애니메이션 코미디 액션 모험
# 34                    다큐멘터리
# 2                    액션 드라마
# 36           멜로/로맨스 판타지 드라마
# 35                      드라마
# 9                    멜로/로맨스
# 37                   코미디 가족
# 3                  미스터리 스릴러
# 14                  코미디 드라마
# 10                      드라마
# 15               범죄 드라마 스릴러
# 28                      드라마
# 20                  드라마 스릴러
# 0   애니메이션 모험 코미디 가족 판타지 뮤지컬
# 25                    다큐멘터리
# 31                  스릴러 드라마
# 29                    SF 액션
# 24                      드라마
# 19                    다큐멘터리
# 33                    다큐멘터리
# 8                    범죄 드라마
# 13         애니메이션 코미디 가족 판타지
# 12                      드라마
# 30                      스릴러
# 23                    애니메이션
# 4                       드라마
# 27                    다큐멘터리
# 21                   공포 스릴러
# 11                      스릴러
# 22            애니메이션 판타지 코미디
# 38                   액션 스릴러
# 7                    공포 스릴러
# 6                멜로/로맨스 코미디
# 18                      드라마
# 17                    다큐멘터리
# 1                     액션 모험
# 5                    스릴러 액션

# %%
movie[]
